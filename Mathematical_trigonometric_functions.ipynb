# %% [markdown]
# # Trigonometricn Functions

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

low = -np.pi
hi = np.pi
N = 50

x = np.linspace(low, hi, N)
c

# %% [markdown]
# y = np.cos(x)
#
# plt.plot(x, y)
# plt.show()

# %%
plt.plot(x, np.sin(x))
plt.plot(x,np.cos(x))
plt.show()

# %%
y = np.tan(x)

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Hyperbolic Function

# %%
low = -np.pi
hi = np.pi
N = 50

x = np.linspace(low, hi, N)
y = np.sinh(x)

plt.plot(x, y)
plt.show( )

# %%
low = -np.pi
hi = np.pi
N = 50

x = np.linspace(low, hi, N)
bbb

# %%
plt.plot(x, np.sinh(x))
plt.plot(x,np.cosh(x))
plt.show()

# %%
y = np.tanh(x)

plt.plot(x, y)
plt.show( )

# %% [markdown]
# # visualisation Of Exponent Functions

# %%
x = np.arange(10)

y = x

plt.plot(x, y)
plt.show( )

# %% [markdown]
# y = np.exp(x)
#
# plt.plot(x, y, 'o-')
# plt.show( )

# %% [markdown]
# # Exponent Minus 1

# %%
y = np.expm1(x)

plt.plot(x, y, 'o-')
plt.show( )

# %%
# 2**x


y = np.exp2(x)

plt.plot(x, y, 'o-')
plt.show( )

# %% [markdown]
# # Logarithms

# %%
x = np.linspace(1, 10, 10)

y = np.log(x)
plt.plot(x, y, 'o-')
plt.show( )

# %%
y = np.log10(x)
plt.plot(x, y, 'o-')
plt.show( )

# %%
y = np.log2(x)
plt.plot(x, y, 'o-')
plt.show( )

# %% [markdown]
# # Convolution

# %%
a = np.array([1, 2, 3])  
b = np.array([4, 5, 6])

print(np.convolve(a, b))
# Out:
# [ 4 13 28 27 18]

# %%
print(np.convolve(a, 4))
# Out:
# [ 4  8 12]

# %%
print(np.convolve(4, 4))
# Out:
# [16]

# %%
print(type(np.convolve(4, 4)))
# Out:
# <class 'numpy.ndarray'>
